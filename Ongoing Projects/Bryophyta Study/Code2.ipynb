# %%
import pandas as pd

# %%
bdf=pd.read_csv("Bryophyta.csv",sep='\t', low_memory=False)
bdf.head()
# Out:
#        gbifID                            datasetKey  \
# 0  3384878258  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1  4076249909  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2  4062971727  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3  3407897699  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4  3456210060  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                                         occurrenceID  kingdom     phylum  \
# 0  https://www.inaturalist.org/observations/97146927  Plantae  Bryophyta
# 1  https://www.inaturalist.org/observations/15045...  Plantae  Bryophyta
# 2  https://www.inaturalist.org/observations/15061...  Plantae  Bryophyta
# 3  https://www.inaturalist.org/observations/99728479  Plantae  Bryophyta
# 4  https://www.inaturalist.org/observations/10052...  Plantae  Bryophyta
#
#              class          order            family               genus  \
# 0        Bryopsida       Hypnales  Brachytheciaceae  Pseudoscleropodium
# ...

# %%
bdf.columns
# Out:
# Index(['gbifID', 'datasetKey', 'occurrenceID', 'kingdom', 'phylum', 'class',
#        'order', 'family', 'genus', 'species', 'infraspecificEpithet',
#        'taxonRank', 'scientificName', 'verbatimScientificName',
#        'verbatimScientificNameAuthorship', 'countryCode', 'locality',
#        'stateProvince', 'occurrenceStatus', 'individualCount',
#        'publishingOrgKey', 'decimalLatitude', 'decimalLongitude',
#        'coordinateUncertaintyInMeters', 'coordinatePrecision', 'elevation',
#        'elevationAccuracy', 'depth', 'depthAccuracy', 'eventDate', 'day',
#        'month', 'year', 'taxonKey', 'speciesKey', 'basisOfRecord',
#        'institutionCode', 'collectionCode', 'catalogNumber', 'recordNumber',
#        'identifiedBy', 'dateIdentified', 'license', 'rightsHolder',
#        'recordedBy', 'typeStatus', 'establishmentMeans', 'lastInterpreted',
#        'mediaType', 'issue'],
#       dtype='object')

# %%
bdf.isna().sum()
# Out:
# gbifID                                   0
# datasetKey                               0
# occurrenceID                             0
# kingdom                                  0
# phylum                                   0
# class                                    0
# order                                    0
# family                                   0
# genus                                  225
# species                               1210
# infraspecificEpithet                277156
# taxonRank                                0
# scientificName                           0
# verbatimScientificName                   0
# verbatimScientificNameAuthorship    278697
# countryCode                            473
# locality                            278697
# stateProvince                          525
# occurrenceStatus                         0
# individualCount                     278697
# publishingOrgKey                         0
# decimalLatitude                        473
# ...

# %% [markdown]
# Making a new dataframe containing only values from non-missing values columns

# %%
print(bdf['phylum'].unique())
print(len(bdf['phylum'].unique()))
print(bdf['class'].unique())
print(len(bdf['class'].unique()))
print(bdf['order'].unique())
print(len(bdf['order'].unique()))
print(bdf['family'].unique())
print(len(bdf['family'].unique()))
print(bdf['genus'].unique())
print(len(bdf['genus'].unique()))
print(bdf['species'].unique())
print(len(bdf['species'].unique()))
# Out:
# ['Bryophyta']
# 1
# ['Bryopsida' 'Polytrichopsida' 'Sphagnopsida' 'Takakiopsida'
#  'Andreaeopsida']
# 5
# ['Hypnales' 'Polytrichales' 'Bryales' 'Dicranales' 'Pottiales'
#  'Encalyptales' 'Grimmiales' 'Sphagnales' 'Hypopterygiales' 'Hedwigiales'
#  'Funariales' 'Hookeriales' 'Aulacomniales' 'Tetraphidales'
#  'Orthotrichales' 'Bartramiales' 'Ptychomniales' 'Scouleriales'
#  'Splachnales' 'Orthodontiales' 'Rhizogoniales' 'Hypnodendrales'
#  'Buxbaumiales' 'Timmiales' 'Takakiales' 'Andreaeales' 'Diphysciales'
#  'Bryoxiphiales' 'Gigaspermales' 'Archidiales' 'Catoscopiales'
#  'Oedipodiales' 'Disceliales']
# 33
# ['Brachytheciaceae' 'Polytrichaceae' 'Bryaceae' 'Leucobryaceae'
#  'Pottiaceae' 'Mniaceae' 'Plagiotheciaceae' 'Neckeraceae' 'Dicranaceae'
#  'Hypnaceae' 'Hylocomiaceae' 'Encalyptaceae' 'Grimmiaceae'
#  'Amblystegiaceae' 'Sphagnaceae' 'Climaciaceae' 'Hypopterygiaceae'
#  'Hedwigiaceae' 'Funariaceae' 'Ditrichaceae' 'Stereodontaceae'
# ...

# %%
NA_Columns= ['depthAccuracy','depth','elevationAccuracy','elevation',
         'coordinatePrecision','individualCount','locality','recordNumber',
         'typeStatus','establishmentMeans','verbatimScientificNameAuthorship','infraspecificEpithet']

df= bdf.drop(columns= NA_Columns)
df.isna().sum()
# Out:
# gbifID                               0
# datasetKey                           0
# occurrenceID                         0
# kingdom                              0
# phylum                               0
# class                                0
# order                                0
# family                               0
# genus                              225
# species                           1210
# taxonRank                            0
# scientificName                       0
# verbatimScientificName               0
# countryCode                        473
# stateProvince                      525
# occurrenceStatus                     0
# publishingOrgKey                     0
# decimalLatitude                    473
# decimalLongitude                   473
# coordinateUncertaintyInMeters    69267
# eventDate                            0
# day                                  0
# month                                0
# year                                 0
# ...

# %%
data= df[['gbifID','kingdom', 'phylum', 'class','order', 'family', 'genus', 'species', 'taxonRank', 'scientificName',
       'verbatimScientificName', 'countryCode', 'stateProvince',
       'decimalLatitude',
       'decimalLongitude','day',
       'month', 'year', 'taxonKey', 'speciesKey',
       'catalogNumber']]

data.head()
# Out:
#        gbifID  kingdom     phylum            class          order  \
# 0  3384878258  Plantae  Bryophyta        Bryopsida       Hypnales
# 1  4076249909  Plantae  Bryophyta  Polytrichopsida  Polytrichales
# 2  4062971727  Plantae  Bryophyta  Polytrichopsida  Polytrichales
# 3  3407897699  Plantae  Bryophyta  Polytrichopsida  Polytrichales
# 4  3456210060  Plantae  Bryophyta        Bryopsida        Bryales
#
#              family               genus                   species taxonRank  \
# 0  Brachytheciaceae  Pseudoscleropodium  Pseudoscleropodium purum   SPECIES
# 1    Polytrichaceae            Atrichum        Atrichum undulatum   SPECIES
# 2    Polytrichaceae            Atrichum       Atrichum angustatum   SPECIES
# 3    Polytrichaceae         Polytrichum   Polytrichum juniperinum   SPECIES
# 4          Bryaceae          Rhodobryum         Rhodobryum roseum   SPECIES
#
#                                 scientificName  ... countryCode  \
# ...
